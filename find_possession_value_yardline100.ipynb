# %%
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import numpy as np
import glob

# %%
temp = []
data = []
subpxp = []
for year in range(2008,2018):    
    path ='/Users/ericherrmann/GitHub/CalFootball_4thDown/NCAA-Football-Data/' + str(year) + 'PXP' # use your path
    allFiles = glob.glob(path + "/*.csv")
    frame = pd.DataFrame()
    list_ = []
    cols = ['gameId', 'driveIndex', 'year', 'week', 'clock', 'quarter', 'down', 'yardLine', 'distance', 'yardsGained',
            'offenseTeam', 'defenseTeam', 'description', 'type',
            'homeScore', 'awayScore', 'homeTeam', 'awayTeam']
    for file_ in allFiles:
        df = pd.read_csv(file_,index_col=None, header=0, usecols=cols)
        list_.append(df)
        subpxp = pd.concat(list_, ignore_index=True)
    temp.append(subpxp)
    data= pd.concat(temp, ignore_index=True)

# %%
import cal_football as cf
pxp = cf.extract_data(data)
badyard = ~((pxp['yrdline100']>=100)|(pxp['yrdline100']<=0))
# possession_values = cf.get_possession_value(ko_and_pos)

# %%
ko_and_poss = cf.extract_kickoffs_and_possessions(pxp)
fgs = cf.extract_field_goals(pxp)
third_downs = cf.extract_third_downs(pxp)
punts = cf.extract_punts(pxp)

ekv,epv_model = cf.epv_model(ko_and_poss)
exp_conv_pct_model = cf.exp_conv_pct_model(third_downs)
exp_net_punt_dist_model = cf.exp_net_punt_dist_model(punts)
exp_fg_prob_model = cf.exp_fg_prob_model(fgs)

# %%
epv_model.to_pickle("./epv_model.pkl")
exp_conv_pct_model.to_pickle("./exp_conv_pct_model.pkl")
exp_net_punt_dist_model.to_pickle("./exp_net_punt_dist_model.pkl")
exp_fg_prob_model.to_pickle("./exp_fg_prob_model.pkl")

# %%
def build_decision_maker(ekv, epv_model, exp_conv_pct_model, 
                         exp_net_punt_dist_model, exp_fg_prob_model):
    
    YRDSTOGO_CAP = 10  # Model restriction
    PUNT_LIM = 29      # Model restriction
    FG_LIM = 63        # Model restriction
    FG_OFFSET = 8      # Field goal placement distance (not including the 10 for the endzone)
    FG_FAIL_RESET = 0  # Where the ball is placed after a failed field goal.  If 0, at the spot.  
                       # Otherwise, at the spot or at the reset spot, whichever is better.
    
    def decision_maker(yrdline100, ydstogo, print_message=False):
        if yrdline100 < 10:
            region = 'Inside10'
        elif yrdline100 < 20:
            region = '10to20'
        else:
            region = 'Beyond20'
            
        # 1. Expected value of going for it
        
        # Value of failing (approximately turning over at same spot)
        conv_fail_yrdline100 = 100 - yrdline100
        conv_fail_epv = -epv_model[conv_fail_yrdline100] 
        
        # Value of converting (approximately at the first down marker)
        if yrdline100 == ydstogo:
            conv_succ_epv = 6 - ekv
        else:
            first_down_yrdline100 = yrdline100 - ydstogo
            conv_succ_epv = epv_model[first_down_yrdline100] -1

        # Conversion Pct
        exp_conv_pct = exp_conv_pct_model[(region, ydstogo)] if ydstogo < YRDSTOGO_CAP else None
        
        # Overall expected value of going for it
        go_ev = exp_conv_pct * conv_succ_epv + (1 - exp_conv_pct) * conv_fail_epv
        
        # 2. Expected value of punting
        
        # Expected next yardline
        if yrdline100 >= PUNT_LIM:
            exp_net_punt_dist = exp_net_punt_dist_model[yrdline100]
            exp_yrdline100 = 100 - yrdline100 + int(exp_net_punt_dist)
            
            # Overall expected value of punting
            punt_ev = -epv_model[exp_yrdline100]
        else:
            punt_ev = None
            
        # 3. Expected value of kicking a field goal
        fg_dist =  yrdline100 + 10 + FG_OFFSET
        if fg_dist <= FG_LIM:
            # Probability of success
            exp_fg_prob = exp_fg_prob_model[fg_dist ]

            # Expected value of field success
            fg_succ_epv = 3 - ekv

            # EPV of field goal fail
            fg_fail_yrdline100 = 100 - yrdline100 - FG_OFFSET
            fg_fail_epv = -epv_model[fg_fail_yrdline100]

            # Overall expected value kicking
            fg_ev = fg_succ_epv * exp_fg_prob + fg_fail_epv * (1 - exp_fg_prob)
        else:
            fg_ev = None
    
        choices = [('go for it', go_ev), ('punt', punt_ev), ('kick', fg_ev)]
        max_val = -100
        for choice, ev in choices:
            if ev is None:
                continue
            if ev > max_val:
                max_val = ev
                decision = choice
    
        if print_message:
            print("Expected Values at {:.2f}".format(yrdline100) + " yard line and dist to go {:.2f}".format(ydstogo))
            print("Go for it: {:.2f}".format(go_ev))
            if punt_ev is not None:
                print("Punt: {:.2f}".format(punt_ev))
            else:
                print("Punt: TOO CLOSE TO PUNT")
            if fg_ev is not None:
                print("FG: {:.2f}".format(fg_ev))
            else:
                print("FG: TOO FAR TO KICK")  
            print()

        return decision
    
    return decision_maker

# Build the decision maker
decision_maker = build_decision_maker(
    ekv, epv_model, exp_conv_pct_model, exp_net_punt_dist_model, exp_fg_prob_model)

# %%
#test
dist = 5 #user input here
rg_max = 101 - dist
rg_min = 0 + dist
for x in range(rg_min, rg_max):
    decision_maker(x, dist, print_message=True)
# Out:
# Expected Values at 5.00 yard line and dist to go 5.00
# Go for it: 2.22
# Punt: TOO CLOSE TO PUNT
# FG: 3.25
#
# Expected Values at 6.00 yard line and dist to go 5.00
# Go for it: 1.35
# Punt: TOO CLOSE TO PUNT
# FG: 3.19
#
# Expected Values at 7.00 yard line and dist to go 5.00
# Go for it: 1.29
# Punt: TOO CLOSE TO PUNT
# FG: 3.13
#
# Expected Values at 8.00 yard line and dist to go 5.00
# Go for it: 1.24
# Punt: TOO CLOSE TO PUNT
# FG: 3.07
#
# Expected Values at 9.00 yard line and dist to go 5.00
# Go for it: 1.18
# Punt: TOO CLOSE TO PUNT
# FG: 3.00
#
# Expected Values at 10.00 yard line and dist to go 5.00
# Go for it: 1.67
# Punt: TOO CLOSE TO PUNT
# FG: 2.93
#
# Expected Values at 11.00 yard line and dist to go 5.00
# Go for it: 1.62
# Punt: TOO CLOSE TO PUNT
# FG: 2.87
#
# Expected Values at 12.00 yard line and dist to go 5.00
# Go for it: 1.56
# Punt: TOO CLOSE TO PUNT
# FG: 2.80
#
# Expected Values at 13.00 yard line and dist to go 5.00
# Go for it: 1.51
# Punt: TOO CLOSE TO PUNT
# FG: 2.72
#
# Expected Values at 14.00 yard line and dist to go 5.00
# Go for it: 1.45
# Punt: TOO CLOSE TO PUNT
# FG: 2.64
#
# Expected Values at 15.00 yard line and dist to go 5.00
# Go for it: 1.40
# Punt: TOO CLOSE TO PUNT
# FG: 2.56
#
# Expected Values at 16.00 yard line and dist to go 5.00
# Go for it: 1.34
# Punt: TOO CLOSE TO PUNT
# FG: 2.48
#
# Expected Values at 17.00 yard line and dist to go 5.00
# Go for it: 1.29
# Punt: TOO CLOSE TO PUNT
# FG: 2.40
#
# Expected Values at 18.00 yard line and dist to go 5.00
# Go for it: 1.23
# Punt: TOO CLOSE TO PUNT
# FG: 2.31
#
# Expected Values at 19.00 yard line and dist to go 5.00
# Go for it: 1.18
# Punt: TOO CLOSE TO PUNT
# FG: 2.22
#
# Expected Values at 20.00 yard line and dist to go 5.00
# Go for it: 1.22
# Punt: TOO CLOSE TO PUNT
# FG: 2.13
#
# Expected Values at 21.00 yard line and dist to go 5.00
# Go for it: 1.17
# Punt: TOO CLOSE TO PUNT
# FG: 2.03
#
# Expected Values at 22.00 yard line and dist to go 5.00
# Go for it: 1.11
# Punt: TOO CLOSE TO PUNT
# FG: 1.93
#
# Expected Values at 23.00 yard line and dist to go 5.00
# Go for it: 1.06
# Punt: TOO CLOSE TO PUNT
# FG: 1.83
#
# Expected Values at 24.00 yard line and dist to go 5.00
# Go for it: 1.00
# Punt: TOO CLOSE TO PUNT
# FG: 1.73
#
# Expected Values at 25.00 yard line and dist to go 5.00
# Go for it: 0.95
# Punt: TOO CLOSE TO PUNT
# FG: 1.62
#
# Expected Values at 26.00 yard line and dist to go 5.00
# Go for it: 0.89
# Punt: TOO CLOSE TO PUNT
# FG: 1.50
#
# Expected Values at 27.00 yard line and dist to go 5.00
# Go for it: 0.84
# Punt: TOO CLOSE TO PUNT
# FG: 1.38
#
# Expected Values at 28.00 yard line and dist to go 5.00
# Go for it: 0.78
# Punt: TOO CLOSE TO PUNT
# FG: 1.26
#
# Expected Values at 29.00 yard line and dist to go 5.00
# Go for it: 0.73
# Punt: -0.90
# FG: 1.12
#
# Expected Values at 30.00 yard line and dist to go 5.00
# Go for it: 0.67
# Punt: -0.90
# FG: 0.97
#
# Expected Values at 31.00 yard line and dist to go 5.00
# Go for it: 0.62
# Punt: -0.84
# FG: 0.82
#
# Expected Values at 32.00 yard line and dist to go 5.00
# Go for it: 0.56
# Punt: -0.84
# FG: 0.66
#
# Expected Values at 33.00 yard line and dist to go 5.00
# Go for it: 0.51
# Punt: -0.79
# FG: 0.47
#
# Expected Values at 34.00 yard line and dist to go 5.00
# Go for it: 0.46
# Punt: -0.79
# FG: 0.28
#
# Expected Values at 35.00 yard line and dist to go 5.00
# Go for it: 0.40
# Punt: -0.73
# FG: 0.09
#
# Expected Values at 36.00 yard line and dist to go 5.00
# Go for it: 0.35
# Punt: -0.73
# FG: -0.11
#
# Expected Values at 37.00 yard line and dist to go 5.00
# Go for it: 0.29
# Punt: -0.68
# FG: -0.31
#
# Expected Values at 38.00 yard line and dist to go 5.00
# Go for it: 0.24
# Punt: -0.62
# FG: -0.51
#
# Expected Values at 39.00 yard line and dist to go 5.00
# Go for it: 0.18
# Punt: -0.62
# FG: -0.72
#
# Expected Values at 40.00 yard line and dist to go 5.00
# Go for it: 0.13
# Punt: -0.57
# FG: -0.93
#
# Expected Values at 41.00 yard line and dist to go 5.00
# Go for it: 0.07
# Punt: -0.57
# FG: -1.15
#
# Expected Values at 42.00 yard line and dist to go 5.00
# Go for it: 0.02
# Punt: -0.51
# FG: -1.37
#
# Expected Values at 43.00 yard line and dist to go 5.00
# Go for it: -0.04
# Punt: -0.51
# FG: -1.59
#
# Expected Values at 44.00 yard line and dist to go 5.00
# Go for it: -0.09
# Punt: -0.46
# FG: -1.82
#
# Expected Values at 45.00 yard line and dist to go 5.00
# Go for it: -0.15
# Punt: -0.46
# FG: -2.06
#
# Expected Values at 46.00 yard line and dist to go 5.00
# Go for it: -0.20
# Punt: -0.46
# FG: TOO FAR TO KICK
#
# Expected Values at 47.00 yard line and dist to go 5.00
# Go for it: -0.26
# Punt: -0.46
# FG: TOO FAR TO KICK
#
# Expected Values at 48.00 yard line and dist to go 5.00
# Go for it: -0.31
# Punt: -0.46
# FG: TOO FAR TO KICK
#
# Expected Values at 49.00 yard line and dist to go 5.00
# Go for it: -0.37
# Punt: -0.46
# FG: TOO FAR TO KICK
#
# Expected Values at 50.00 yard line and dist to go 5.00
# Go for it: -0.42
# Punt: -0.51
# FG: TOO FAR TO KICK
#
# Expected Values at 51.00 yard line and dist to go 5.00
# Go for it: -0.47
# Punt: -0.51
# FG: TOO FAR TO KICK
#
# Expected Values at 52.00 yard line and dist to go 5.00
# Go for it: -0.53
# Punt: -0.57
# FG: TOO FAR TO KICK
#
# Expected Values at 53.00 yard line and dist to go 5.00
# Go for it: -0.58
# Punt: -0.57
# FG: TOO FAR TO KICK
#
# Expected Values at 54.00 yard line and dist to go 5.00
# Go for it: -0.64
# Punt: -0.62
# FG: TOO FAR TO KICK
#
# Expected Values at 55.00 yard line and dist to go 5.00
# Go for it: -0.69
# Punt: -0.68
# FG: TOO FAR TO KICK
#
# Expected Values at 56.00 yard line and dist to go 5.00
# Go for it: -0.75
# Punt: -0.68
# FG: TOO FAR TO KICK
#
# Expected Values at 57.00 yard line and dist to go 5.00
# Go for it: -0.80
# Punt: -0.73
# FG: TOO FAR TO KICK
#
# Expected Values at 58.00 yard line and dist to go 5.00
# Go for it: -0.86
# Punt: -0.79
# FG: TOO FAR TO KICK
#
# Expected Values at 59.00 yard line and dist to go 5.00
# Go for it: -0.91
# Punt: -0.79
# FG: TOO FAR TO KICK
#
# Expected Values at 60.00 yard line and dist to go 5.00
# Go for it: -0.97
# Punt: -0.84
# FG: TOO FAR TO KICK
#
# Expected Values at 61.00 yard line and dist to go 5.00
# Go for it: -1.02
# Punt: -0.90
# FG: TOO FAR TO KICK
#
# Expected Values at 62.00 yard line and dist to go 5.00
# Go for it: -1.08
# Punt: -0.95
# FG: TOO FAR TO KICK
#
# Expected Values at 63.00 yard line and dist to go 5.00
# Go for it: -1.13
# Punt: -0.95
# FG: TOO FAR TO KICK
#
# Expected Values at 64.00 yard line and dist to go 5.00
# Go for it: -1.19
# Punt: -1.01
# FG: TOO FAR TO KICK
#
# Expected Values at 65.00 yard line and dist to go 5.00
# Go for it: -1.24
# Punt: -1.06
# FG: TOO FAR TO KICK
#
# Expected Values at 66.00 yard line and dist to go 5.00
# Go for it: -1.30
# Punt: -1.11
# FG: TOO FAR TO KICK
#
# Expected Values at 67.00 yard line and dist to go 5.00
# Go for it: -1.35
# Punt: -1.17
# FG: TOO FAR TO KICK
#
# Expected Values at 68.00 yard line and dist to go 5.00
# Go for it: -1.40
# Punt: -1.22
# FG: TOO FAR TO KICK
#
# Expected Values at 69.00 yard line and dist to go 5.00
# Go for it: -1.46
# Punt: -1.22
# FG: TOO FAR TO KICK
#
# Expected Values at 70.00 yard line and dist to go 5.00
# Go for it: -1.51
# Punt: -1.28
# FG: TOO FAR TO KICK
#
# Expected Values at 71.00 yard line and dist to go 5.00
# Go for it: -1.57
# Punt: -1.33
# FG: TOO FAR TO KICK
#
# Expected Values at 72.00 yard line and dist to go 5.00
# Go for it: -1.62
# Punt: -1.39
# FG: TOO FAR TO KICK
#
# Expected Values at 73.00 yard line and dist to go 5.00
# Go for it: -1.68
# Punt: -1.44
# FG: TOO FAR TO KICK
#
# Expected Values at 74.00 yard line and dist to go 5.00
# Go for it: -1.73
# Punt: -1.50
# FG: TOO FAR TO KICK
#
# Expected Values at 75.00 yard line and dist to go 5.00
# Go for it: -1.79
# Punt: -1.55
# FG: TOO FAR TO KICK
#
# Expected Values at 76.00 yard line and dist to go 5.00
# Go for it: -1.84
# Punt: -1.61
# FG: TOO FAR TO KICK
#
# Expected Values at 77.00 yard line and dist to go 5.00
# Go for it: -1.90
# Punt: -1.66
# FG: TOO FAR TO KICK
#
# Expected Values at 78.00 yard line and dist to go 5.00
# Go for it: -1.95
# Punt: -1.72
# FG: TOO FAR TO KICK
#
# Expected Values at 79.00 yard line and dist to go 5.00
# Go for it: -2.01
# Punt: -1.77
# FG: TOO FAR TO KICK
#
# Expected Values at 80.00 yard line and dist to go 5.00
# Go for it: -2.06
# Punt: -1.83
# FG: TOO FAR TO KICK
#
# Expected Values at 81.00 yard line and dist to go 5.00
# Go for it: -2.12
# Punt: -1.88
# FG: TOO FAR TO KICK
#
# Expected Values at 82.00 yard line and dist to go 5.00
# Go for it: -2.17
# Punt: -1.94
# FG: TOO FAR TO KICK
#
# Expected Values at 83.00 yard line and dist to go 5.00
# Go for it: -2.23
# Punt: -1.99
# FG: TOO FAR TO KICK
#
# Expected Values at 84.00 yard line and dist to go 5.00
# Go for it: -2.28
# Punt: -2.04
# FG: TOO FAR TO KICK
#
# Expected Values at 85.00 yard line and dist to go 5.00
# Go for it: -2.33
# Punt: -2.10
# FG: TOO FAR TO KICK
#
# Expected Values at 86.00 yard line and dist to go 5.00
# Go for it: -2.39
# Punt: -2.15
# FG: TOO FAR TO KICK
#
# Expected Values at 87.00 yard line and dist to go 5.00
# Go for it: -2.44
# Punt: -2.21
# FG: TOO FAR TO KICK
#
# Expected Values at 88.00 yard line and dist to go 5.00
# Go for it: -2.50
# Punt: -2.26
# FG: TOO FAR TO KICK
#
# Expected Values at 89.00 yard line and dist to go 5.00
# Go for it: -2.55
# Punt: -2.32
# FG: TOO FAR TO KICK
#
# Expected Values at 90.00 yard line and dist to go 5.00
# Go for it: -2.61
# Punt: -2.37
# FG: TOO FAR TO KICK
#
# Expected Values at 91.00 yard line and dist to go 5.00
# Go for it: -2.66
# Punt: -2.43
# FG: TOO FAR TO KICK
#
# Expected Values at 92.00 yard line and dist to go 5.00
# Go for it: -2.72
# Punt: -2.48
# FG: TOO FAR TO KICK
#
# Expected Values at 93.00 yard line and dist to go 5.00
# Go for it: -2.77
# Punt: -2.54
# FG: TOO FAR TO KICK
#
# Expected Values at 94.00 yard line and dist to go 5.00
# Go for it: -2.83
# Punt: -2.65
# FG: TOO FAR TO KICK
