# %% [markdown]
# ## Most Similar Games
#
# Determine n most similar matchups based off of the ESPN efficiency rating for 1. Cal's offense and 2. the opponent's defense. I know we talked about determining the most similar matchups based off of 4 parameters (the offense and defense of both teams), but becuase we didn't decide how to weight the 4 parameters I use only 1. and 2.

# %%
import pandas as pd
import numpy as np
import urllib.request
from bs4 import BeautifulSoup
from collections import Counter
import csv
import re
from get_data import get_data

# %%
"""Extracts ESPN Offensive and Defensive Efficieny Ratings from 2005-2017

Returns:
    3 Pandas Data Frames: 
        1. awayTeam, homeTeam, year
        2. Def. Rating, Off. Rating, Team, year
        3. pxp data

"""

def get_ratings():
    
    def extract_team_name(x):
            match = re.search('\>([a-zA-Z\s\&\;\(\)\.\']*)\<\/a\>', x)
            if match:
                found = match.group(1)
            return found

    def extract_rating(x):
            match = re.search('\>(.*)\<', x)
            if match:
                found = match.group(1)
            return found
        
    pxp_data = get_data('all')

    game_data = pxp_data.groupby(pxp_data.gameId).first().loc[:, ["awayTeam", "homeTeam", "year"]]
    game_data = game_data.loc[game_data.year >= 2005]
    
    ### Remove teams that were not DI for all years between 2005 and 2017
    teams_to_remove = ["Appalachian St", "Texas State", "W Kentucky", "UMass", "Ga Southern", "Georgia State", "South Alabama"]

    for x in teams_to_remove:
        team_away = game_data.awayTeam == x
        team_home = game_data.homeTeam == x
        team_home = ~team_home.values
        team_away = ~team_away.values
        game_data = game_data[team_home*team_away]
                
    teams = []
    off_eff = []
    def_eff = []
    year = []

    ### Start of Web Scraper
    for x in np.arange(2005, 2018):
        url = "http://www.espn.com/college-football/statistics/teamratings/_/year/" + str(x) + "/sort/offEfficiency/tab/efficiency"
        page = urllib.request.urlopen(url).read()
        soup = BeautifulSoup(page)

        raw_team_name = []
        raw_off_rating = []
        raw_def_rating = []

        for tr in soup.find_all('tr')[1:]:
            tds = tr.find_all('td')
            team = tds[1]
            off_rating = tds[2]
            def_rating = tds[3]

            raw_team_name.append(team)
            raw_off_rating.append(off_rating)
            raw_def_rating.append(def_rating)

        raw_team_name = [str(x) for x in raw_team_name]
        raw_team_name = raw_team_name[1:]
        raw_team_name = np.array(raw_team_name)

        column_headers = ~np.array(["TEAM" in x for x in raw_team_name])
        raw_team_name = raw_team_name[column_headers]
        team_names = [extract_team_name(x) for x in raw_team_name]

        raw_off_rating = raw_off_rating[1:]
        raw_off_rating = [str(x) for x in raw_off_rating]
        raw_off_rating = np.array(raw_off_rating)
        raw_off_rating = raw_off_rating[column_headers]

        off_ratings = np.array([extract_rating(x) for x in raw_off_rating])
        off_ratings = [float(x) for x in off_ratings]

        raw_def_rating = raw_def_rating[1:]
        raw_def_rating = [str(x) for x in raw_def_rating]
        raw_def_rating = np.array(raw_def_rating)
        raw_def_rating = raw_def_rating[column_headers]

        def_ratings = np.array([extract_rating(x) for x in raw_def_rating])
        def_ratings = [float(x) for x in def_ratings]

        teams.append(team_names)
        off_eff.append(off_ratings)
        def_eff.append(def_ratings)
        year.append([x]*len(team_names))

    teams = sum(teams, [])
    off_eff = sum(off_eff, [])
    def_eff = sum(def_eff, [])
    year = sum(year, [])
    
    ### Create Rating DataFrame
    rating_data = pd.DataFrame({"Team" : teams, "Off. Rating" : off_eff, "Year" : year, "Def. Rating" : def_eff})

    ### Rename Teams in the rating data so that it matches the game data
    rating_data.Team = pd.Series([x.replace("Texas A&amp;M'", "Texas A&M") for x in rating_data.Team.values])
    rating_data.Team = pd.Series([x.replace("Texas A&amp;M", "Texas A&M") for x in rating_data.Team.values])
    rating_data.Team = pd.Series([x.replace("Mich. St.", "Michigan State") for x in rating_data.Team.values])
    rating_data.Team = pd.Series([x.replace("Oregon St", "Oregon State") for x in rating_data.Team.values])
    rating_data.Team = pd.Series([x.replace("Oregon Stateate", "Oregon State") for x in rating_data.Team.values])

    ### Remove games where teams are playing an opponent for which no rating data exists
    keep_games = []
    
    for index, x in game_data.iterrows():
        keep_game = x.awayTeam in rating_data.Team.values and x.homeTeam in rating_data.Team.values
        keep_games.append(keep_game)

    keep_games = np.array(keep_games)
    game_data = game_data.loc[keep_games]
    
    return game_data, rating_data, pxp_data

# %%
"""Uses ESPN Efficiency data from above to find the n most similar games

Parameters: 
    off_rating - Offensive Rating of team of interest
    def_rating - Deffensive Rating of team of interest
    n - number of most similar games to be returned
    game_data - First Dataframe returned by get_ratings()
    rating_data - Second Dataframe returned by get_ratings()
    
Returns: 
    2 Objects:
        1. Array of lists where each list has the following elements:
            1. String - name of AWAY team
            2. String - name of HOME team
            3. Int - year of matchup
            4. Boolean - True if home team is on offense and away team is on defense (for False the sides are swapped)
            5. Float - Root Mean Squared Error of matchup to matchup of interest
        2. Pxp data of games in Array
        
"""

def most_similar(off_rating, def_rating, n, game_data, rating_data, pxp_data):
    RMSEs = []
    home_off_away_def = []

    for index, x in game_data.iterrows():
        x_year_ratings = rating_data.loc[rating_data.Year == x.year]
        
        away_def = float(x_year_ratings.loc[x_year_ratings.Team == x.awayTeam].loc[:, "Def. Rating"].values)
        away_off = float(x_year_ratings.loc[x_year_ratings.Team == x.awayTeam].loc[:, "Off. Rating"].values)
        home_def = float(x_year_ratings.loc[x_year_ratings.Team == x.homeTeam].loc[:, "Def. Rating"].values)
        home_off = float(x_year_ratings.loc[x_year_ratings.Team == x.homeTeam].loc[:, "Off. Rating"].values)
    
        ### Use Root Mean Squared Error for Test Statistic
        rmse_away_home = np.sqrt(((def_rating - away_def)**2 + (off_rating - home_off)**2)/2)
        rmse_home_away = np.sqrt(((def_rating - home_def)**2 + (off_rating - away_off)**2)/2)
        
        if rmse_away_home < rmse_home_away:
            home_off_away_def.append(True)
        else:
            home_off_away_def.append(False)
    
        game_rmse = np.array([rmse_away_home, rmse_home_away])
        RMSEs.append(game_rmse[np.argmin(game_rmse)])
    
    game_data.loc[:,"RMSEs"] = RMSEs
    game_data.loc[:, "home_off_away_def"] = home_off_away_def
    
    game_list = game_data.sort_values("RMSEs").reset_index().loc[0:n, ["awayTeam", "homeTeam", "year", "home_off_away_def", "RMSEs"]].values
    
    return_data = pd.DataFrame(columns = pxp_data.columns)

    for x in game_list:
        bool_away_team = pxp_data.awayTeam == x[0]
        bool_home_team = pxp_data.homeTeam == x[1]
        bool_year = pxp_data.year == x[2]
        return_data = return_data.append(pxp_data.loc[bool_away_team & bool_home_team & bool_year, :])
        
    bool_rep_arr = []
    for index, row in game_data.iterrows():
        num_plays_one_game = return_data.loc[return_data.gameId == index]
        bool_rep_arr.append(np.repeat(row["home_off_away_def"], (len(num_plays_one_game))))
       
    bool_rep_arr = np.concatenate(bool_rep_arr)
    return_data["home_off_away_def"] = bool_rep_arr
    return game_list, return_data

# %% [markdown]
# Here is an example of how the previous functions are used:

# %%
game_data, rating_data, pxp_data = get_ratings()
game_list, return_data = most_similar(off_rating = 80, def_rating = 90, n = 10, game_data = game_data, rating_data = rating_data, pxp_data=pxp_data)
# Out:
# /Users/jeremylevitt/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/jeremylevitt/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
game_data
# Out:
#                   awayTeam         homeTeam  year      RMSEs  \
# gameId
# 252440009           Temple    Arizona State  2005  52.189271
# 252440041          Buffalo            UConn  2005  51.061629
# 252440154       Vanderbilt      Wake Forest  2005  30.636579
# 252440202        Minnesota            Tulsa  2005  22.768948
# 252440248           Oregon          Houston  2005  21.778544
# 252440265            Idaho    Washington St  2005  42.851488
# 252442132       E Michigan       Cincinnati  2005  47.620164
# 252442579              UCF   South Carolina  2005  27.876244
# 252450254          Arizona             Utah  2005  22.742141
# 252452117          Indiana    Cent Michigan  2005  43.637140
# 252460002     Georgia Tech           Auburn  2005   8.605231
# 252460021             UCLA  San Diego State  2005  24.203306
# 252460038   Colorado State         Colorado  2005  27.992946
# 252460057          Wyoming          Florida  2005  26.815854
# 252460061      Boise State          Georgia  2005  25.926820
# 252460062              USC           Hawaii  2005  11.501739
# 252460077             Ohio     Northwestern  2005  34.311806
# 252460127       Kent State   Michigan State  2005  38.017101
# 252460130       N Illinois         Michigan  2005  14.572749
# 252460151             Duke              ECU  2005  47.648820
# 252460166             UTEP    New Mexico St  2005  54.186714
# 252460194       Miami (OH)       Ohio State  2005  20.018117
# 252460201              TCU         Oklahoma  2005  22.201914
# 252460213              USF       Penn State  2005  12.414709
# 252460221       Notre Dame             Pitt  2005  20.708694
# 252460228        Texas A&M          Clemson  2005  22.249157
# 252460252   Boston College              BYU  2005  11.450982
# 252460275    Bowling Green        Wisconsin  2005  25.900000
# 252460333    Mid Tennessee          Alabama  2005  31.673490
# 252460356          Rutgers         Illinois  2005  35.609058
# ...                    ...              ...   ...        ...
# 400945280   Colorado State       New Mexico  2017  43.717788
# 400945281       Utah State             UNLV  2017  30.070750
# 400945282     Fresno State  San Diego State  2017  26.569908
# 400945283        Air Force   Colorado State  2017  48.373805
# 400945284      Boise State       Utah State  2017  22.573657
# 400945285       New Mexico          Wyoming  2017  42.492352
# 400945286             UNLV     Fresno State  2017  28.663304
# 400945287  San Diego State          Hawai'i  2017  36.203936
# 400945288   San Jose State              BYU  2017  56.828602
# 400945289           Nevada      Boise State  2017  32.280722
# 400945290   Colorado State          Wyoming  2017  20.025983
# 400945291       Utah State       New Mexico  2017  43.613358
# 400945292              BYU     Fresno State  2017  35.585461
# 400945293          Hawai'i             UNLV  2017  55.979461
# 400945294  San Diego State   San Jose State  2017  51.542458
# 400945295          Wyoming        Air Force  2017  24.293312
# 400945296      Boise State   Colorado State  2017  21.474753
# 400945297     Fresno State          Hawai'i  2017  34.492028
# 400945298   San Jose State           Nevada  2017  54.281166
# 400945299              BYU             UNLV  2017  37.095148
# 400945300        Air Force      Boise State  2017  25.500784
# 400945301   San Jose State   Colorado State  2017  48.637074
# 400945302             UNLV       New Mexico  2017  48.144886
# 400945303          Hawai'i       Utah State  2017  35.670226
# 400945304     Fresno State          Wyoming  2017  26.419690
# 400945305           Nevada  San Diego State  2017  33.418633
# 400981507            Miami              FSU  2017  16.000000
# 400981508     Georgia Tech            Miami  2017  13.572951
# 400985386              USF            UConn  2017  36.992026
# 400985406          Memphis              UCF  2017  17.081569
#
#            home_off_away_def
# gameId
# 252440009               True
# 252440041              False
# 252440154              False
# 252440202              False
# 252440248               True
# 252440265               True
# 252442132              False
# 252442579              False
# 252450254               True
# 252452117              False
# 252460002               True
# 252460021              False
# 252460038              False
# 252460057               True
# 252460061              False
# 252460062               True
# 252460077               True
# 252460127               True
# 252460130              False
# 252460151               True
# 252460166               True
# 252460194              False
# 252460201              False
# 252460213               True
# 252460221              False
# 252460228              False
# 252460252               True
# 252460275              False
# 252460333              False
# 252460356               True
# ...                      ...
# 400945280              False
# 400945281               True
# 400945282               True
# 400945283              False
# 400945284              False
# 400945285              False
# 400945286              False
# 400945287               True
# 400945288              False
# 400945289              False
# 400945290              False
# 400945291               True
# 400945292               True
# 400945293              False
# 400945294              False
# 400945295               True
# 400945296               True
# 400945297               True
# 400945298               True
# 400945299               True
# 400945300              False
# 400945301               True
# 400945302              False
# 400945303              False
# 400945304              False
# 400945305              False
# 400981507              False
# 400981508              False
# 400985386               True
# 400985406              False
#
# [7486 rows x 5 columns]

# %%
return_data
# Out:
#      awayAbbr awayId awayScore awayTeam  clock defenseAbbr defenseId  \
# 2312      FLA     57         0  Florida  14:24         FLA        57
# 2313      FLA     57         0  Florida  13:47         FLA        57
# 2314      FLA     57         0  Florida  13:38         FLA        57
# 2315      FLA     57         0  Florida  13:03         FLA        57
# 2316      FLA     57         0  Florida  12:14         FLA        57
# 2317      FLA     57         0  Florida  11:27         FLA        57
# 2318      FLA     57         0  Florida  10:58         FLA        57
# 2319      FLA     57         0  Florida  10:42         FLA        57
# 2320      FLA     57         0  Florida  10:37         FLA        57
# 2321      FLA     57         0  Florida  10:37         FLA        57
# 2322      FLA     57         0  Florida   9:47         ALA       333
# 2323      FLA     57         0  Florida   9:46         ALA       333
# 2324      FLA     57         0  Florida   9:38         ALA       333
# 2325      FLA     57         0  Florida   9:29         ALA       333
# 2326      FLA     57         0  Florida   9:22         FLA        57
# 2327      FLA     57         0  Florida   8:38         FLA        57
# 2328      FLA     57         0  Florida   7:56         FLA        57
# 2329      FLA     57         0  Florida   7:40         FLA        57
# 2330      FLA     57         0  Florida   7:03         FLA        57
# 2331      FLA     57         0  Florida   6:49         FLA        57
# 2332      FLA     57         0  Florida   6:30         FLA        57
# 2333      FLA     57         0  Florida   6:30         FLA        57
# 2334      FLA     57         0  Florida   5:50         FLA        57
# 2335      FLA     57         0  Florida   5:33         FLA        57
# 2336      FLA     57         0  Florida   5:33         FLA        57
# 2337      FLA     57         0  Florida   4:08         FLA        57
# 2338      FLA     57         0  Florida   4:38         ALA       333
# 2339      FLA     57         0  Florida   4:30         ALA       333
# 2340      FLA     57         0  Florida   4:08         ALA       333
# 2341      FLA     57         0  Florida   3:29         ALA       333
# ...       ...    ...       ...      ...    ...         ...       ...
# 1941      FLA     57        42  Florida   9:45         UGA        61
# 1942      FLA     57        42  Florida   9:13         UGA        61
# 1943      FLA     57        42  Florida   9:03         UGA        61
# 1944      FLA     57        42  Florida   8:04         UGA        61
# 1945      FLA     57        42  Florida   8:04         UGA        61
# 1946      FLA     57        42  Florida   7:28         UGA        61
# 1947      FLA     57        48  Florida   7:21         UGA        61
# 1948      FLA     57        49  Florida   7:21         UGA        61
# 1949      FLA     57        49  Florida   7:21         UGA        61
# 1950      FLA     57        49  Florida   7:08         FLA        57
# 1951      FLA     57        49  Florida   6:15         FLA        57
# 1952      FLA     57        49  Florida   5:50         FLA        57
# 1953      FLA     57        49  Florida   5:10         FLA        57
# 1954      FLA     57        49  Florida   4:36         FLA        57
# 1955      FLA     57        49  Florida   4:27         FLA        57
# 1956      FLA     57        49  Florida   4:21         FLA        57
# 1957      FLA     57        49  Florida   3:50         FLA        57
# 1958      FLA     57        49  Florida   3:40         FLA        57
# 1959      FLA     57        49  Florida   3:09         FLA        57
# 1960      FLA     57        49  Florida   3:09         FLA        57
# 1961      FLA     57        49  Florida   3:09         FLA        57
# 1962      FLA     57        49  Florida   2:24         UGA        61
# 1963      FLA     57        49  Florida   2:05         UGA        61
# 1964      FLA     57        49  Florida   1:38         UGA        61
# 1965      FLA     57        49  Florida   1:28         UGA        61
# 1966      FLA     57        49  Florida   0:48         UGA        61
# 1967      FLA     57        49  Florida   0:44         UGA        61
# 1968      FLA     57        49  Florida   0:30         UGA        61
# 1969      FLA     57        49  Florida   0:30         UGA        61
# 1970      FLA     57        49  Florida   0:11         UGA        61
#
#      defenseTeam                                        description distance  \
# 2312     Florida  Greg McElroy pass complete to Julio Jones for ...       10
# 2313     Florida       Mark Ingram rush for 6 yards to the Alab 46.       10
# 2314     Florida  Greg McElroy rush for 7 yards to the Fla 47 fo...        4
# 2315     Florida        Mark Ingram rush for 2 yards to the Fla 45.       10
# 2316     Florida  Greg McElroy pass complete to Marquis Maze for...        8
# 2317     Florida  Greg McElroy pass complete to Colin Peek for 2...       10
# 2318     Florida       Roy Upchurch rush for 3 yards to the Fla 31.        8
# 2319     Florida       Greg McElroy pass incomplete to Julio Jones.        5
# 2320     Florida              Leigh Tiffin 48 yard field goal GOOD.        5
# 2321     Florida  Leigh Tiffin kickoff for 70 yards returned by ...       -1
# 2322     Alabama  Tim Tebow pass complete to Aaron Hernandez for...       10
# 2323     Alabama        Tim Tebow pass incomplete to Jeffery Demps.        8
# 2324     Alabama         Tim Tebow pass incomplete to David Nelson.        8
# 2325     Alabama        Chas Henry punt for 48 yards out-of-bounds.        8
# 2326     Florida  Greg McElroy pass complete to Colin Peek for 1...       10
# 2327     Florida  Mark Ingram rush for 7 yards to the 50 yard line.       10
# 2328     Florida  Mark Ingram rush for 15 yards to the Fla 35 fo...        3
# 2329     Florida   Trent Richardson rush for 3 yards to the Fla 32.       10
# 2330     Florida       Greg McElroy pass incomplete to Julio Jones.        7
# 2331     Florida  Greg McElroy pass complete to Marquis Maze for...        7
# 2332     Florida        Mark Ingram rush for 8 yards to the Fla 10.       10
# 2333     Florida  ALABAMA penalty 5 yard illegal procedure accep...        2
# 2334     Florida           FLORIDA penalty 8 yard holding accepted.        7
# 2335     Florida      Mark Ingram rush for 7 yards for a TOUCHDOWN.        0
# 2336     Florida                   Leigh Tiffin extra point MISSED.       -1
# 2337     Florida  Leigh Tiffin kickoff for 70 yards returned by ...       -1
# 2338     Alabama       Chris Rainey rush for 9 yards to the Fla 22.       10
# 2339     Alabama  Tim Tebow pass complete to Deonte Thompson for...        1
# 2340     Alabama                         Tim Tebow pass incomplete.       10
# 2341     Alabama          Tim Tebow rush for 3 yards to the Fla 43.       10
# ...          ...                                                ...      ...
# 1941     Georgia  Emmanuel Moody rush for 28 yards to the Geo 38...       10
# 1942     Georgia  John Brantley pass complete to Deonte Thompson...       10
# 1943     Georgia  John Brantley pass complete to Deonte Thompson...        7
# 1944     Georgia     Emmanuel Moody rush for no gain to the Geo 12.       10
# 1945     Georgia   Georgia penalty 5 yard offside defense accepted.       10
# 1946     Georgia                     John Brantley pass incomplete.        5
# 1947     Georgia  John Brantley pass complete to Deonte Thompson...        5
# 1948     Georgia                Jonathan Phillips extra point GOOD.       -1
# 1949     Georgia  Caleb Sturgis kickoff for 70 yards for a touch...       -1
# 1950     Florida     Richard Samuel rush for 5 yards to the Geo 25.       10
# 1951     Florida  Joe Cox rush for 13 yards to the Geo 38 for a ...        5
# 1952     Florida  Richard Samuel rush for a loss of 1 yard to th...       10
# 1953     Florida  Richard Samuel rush for 22 yards to the Fla 41...       11
# 1954     Florida     Richard Samuel rush for 6 yards to the Fla 35.       10
# 1955     Florida                           Joe Cox pass incomplete.        4
# 1956     Florida                           Joe Cox pass incomplete.        4
# 1957     Florida  Joe Cox pass complete to Israel Troupe for 9 y...        4
# 1958     Florida     Richard Samuel rush for 7 yards to the Fla 19.       10
# 1959     Florida  Joe Cox pass complete to Aron White for 19 yar...        3
# 1960     Florida                      Blair Walsh extra point GOOD.       -1
# 1961     Florida  Blair Walsh kickoff for 57 yards returned by B...       -1
# 1962     Georgia      Emmanuel Moody rush for no gain to the Fla 8.       10
# 1963     Georgia      John Brantley rush for 6 yards to the Fla 14.       10
# 1964     Georgia  Georgia penalty 7 yard pass interference accep...        4
# 1965     Georgia     Emmanuel Moody rush for 3 yards to the Fla 24.       10
# 1966     Georgia  Emmanuel Moody rush for 15 yards to the Fla 39...        7
# 1967     Georgia                      Timeout FLORIDA, clock 00:44.       10
# 1968     Georgia  Emmanuel Moody rush for 16 yards to the Geo 45...       10
# 1969     Georgia                      Timeout FLORIDA, clock 00:30.       10
# 1970     Georgia     Emmanuel Moody rush for 9 yards to the Geo 36.       10
#
#             ...        offenseTeam playIndex quarter                type  \
# 2312        ...            Alabama         0       1     Pass Completion
# 2313        ...            Alabama         1       1                Rush
# 2314        ...            Alabama         2       1                Rush
# 2315        ...            Alabama         3       1                Rush
# 2316        ...            Alabama         4       1     Pass Completion
# 2317        ...            Alabama         5       1     Pass Completion
# 2318        ...            Alabama         6       1                Rush
# 2319        ...            Alabama         7       1   Pass Incompletion
# 2320        ...            Alabama         8       1     Field Goal Good
# 2321        ...            Alabama         9       1             Kickoff
# 2322        ...            Florida         0       1     Pass Completion
# 2323        ...            Florida         1       1   Pass Incompletion
# 2324        ...            Florida         2       1   Pass Incompletion
# 2325        ...            Florida         3       1                Punt
# 2326        ...            Alabama         0       1     Pass Completion
# 2327        ...            Alabama         1       1                Rush
# 2328        ...            Alabama         2       1                Rush
# 2329        ...            Alabama         3       1                Rush
# 2330        ...            Alabama         4       1   Pass Incompletion
# 2331        ...            Alabama         5       1     Pass Completion
# 2332        ...            Alabama         6       1                Rush
# 2333        ...            Alabama         7       1             Penalty
# 2334        ...            Alabama         8       1             Penalty
# 2335        ...            Alabama         9       1                Rush
# 2336        ...            Alabama        10       1  Extra Point Missed
# 2337        ...            Alabama        11       1             Kickoff
# 2338        ...            Florida         0       1                Rush
# 2339        ...            Florida         1       1     Pass Completion
# 2340        ...            Florida         2       1   Pass Incompletion
# 2341        ...            Florida         3       1                Rush
# ...         ...                ...       ...     ...                 ...
# 1941        ...            Florida         0       4                Rush
# 1942        ...            Florida         1       4     Pass Completion
# 1943        ...            Florida         2       4     Pass Completion
# 1944        ...            Florida         3       4                Rush
# 1945        ...            Florida         4       4             Penalty
# 1946        ...            Florida         5       4   Pass Incompletion
# 1947        ...            Florida         6       4     Pass Completion
# 1948        ...            Florida         7       4    Extra Point Good
# 1949        ...            Florida         8       4             Kickoff
# 1950        ...            Georgia         0       4                Rush
# 1951        ...            Georgia         1       4                Rush
# 1952        ...            Georgia         2       4                Rush
# 1953        ...            Georgia         3       4                Rush
# 1954        ...            Georgia         4       4                Rush
# 1955        ...            Georgia         5       4   Pass Incompletion
# 1956        ...            Georgia         6       4   Pass Incompletion
# 1957        ...            Georgia         7       4     Pass Completion
# 1958        ...            Georgia         8       4                Rush
# 1959        ...            Georgia         9       4     Pass Completion
# 1960        ...            Georgia        10       4    Extra Point Good
# 1961        ...            Georgia        11       4             Kickoff
# 1962        ...            Florida         0       4                Rush
# 1963        ...            Florida         1       4                Rush
# 1964        ...            Florida         2       4             Penalty
# 1965        ...            Florida         3       4                Rush
# 1966        ...            Florida         4       4                Rush
# 1967        ...            Florida         5       4             Timeout
# 1968        ...            Florida         6       4                Rush
# 1969        ...            Florida         7       4             Timeout
# 1970        ...            Florida         8       4                Rush
#
#      wallclock week yardLine yardsGained  year home_off_away_def
# 2312       NaN   14       22          18  2009              True
# 2313       NaN   14       40           6  2009              True
# 2314       NaN   14       46           7  2009              True
# 2315       NaN   14       53           2  2009              True
# 2316       NaN   14       55           9  2009              True
# 2317       NaN   14       64           2  2009              True
# 2318       NaN   14       66           3  2009              True
# 2319       NaN   14       69           0  2009              True
# 2320       NaN   14       69          48  2009              True
# 2321       NaN   14       30          26  2009              True
# 2322       NaN   14       74           2  2009              True
# 2323       NaN   14       72           0  2009              True
# 2324       NaN   14       72           0  2009              True
# 2325       NaN   14       72           0  2009              True
# 2326       NaN   14       24          19  2009              True
# 2327       NaN   14       43           7  2009              True
# 2328       NaN   14       50          15  2009              True
# 2329       NaN   14       65           3  2009              True
# 2330       NaN   14       68           0  2009              True
# 2331       NaN   14       68          14  2009              True
# 2332       NaN   14       82           8  2009              True
# 2333       NaN   14       90           0  2009              True
# 2334       NaN   14       85           0  2009              True
# 2335       NaN   14       93           7  2009              True
# 2336       NaN   14       97           0  2009              True
# 2337       NaN   14       30          26  2009              True
# 2338       NaN   14       87           9  2009              True
# 2339       NaN   14       78          18  2009              True
# 2340       NaN   14       60           0  2009              True
# 2341       NaN   14       60           3  2009              True
# ...        ...  ...      ...         ...   ...               ...
# 1941       NaN   10       66          28  2008              True
# 1942       NaN   10       38           3  2008              True
# 1943       NaN   10       35          23  2008              True
# 1944       NaN   10       12           0  2008              True
# 1945       NaN   10       12           0  2008              True
# 1946       NaN   10        7           0  2008              True
# 1947       NaN   10        7           7  2008              True
# 1948       NaN   10        3           0  2008              True
# 1949       NaN   10       70           0  2008              True
# 1950       NaN   10       20           5  2008              True
# 1951       NaN   10       25          13  2008              True
# 1952       NaN   10       38          -1  2008              True
# 1953       NaN   10       37          22  2008              True
# 1954       NaN   10       59           6  2008              True
# 1955       NaN   10       65           0  2008              True
# 1956       NaN   10       65           0  2008              True
# 1957       NaN   10       65           9  2008              True
# 1958       NaN   10       74           7  2008              True
# 1959       NaN   10       81          19  2008              True
# 1960       NaN   10       97           0  2008              True
# 1961       NaN   10       30           5  2008              True
# 1962       NaN   10       92           0  2008              True
# 1963       NaN   10       92           6  2008              True
# 1964       NaN   10       86           0  2008              True
# 1965       NaN   10       79           3  2008              True
# 1966       NaN   10       76          15  2008              True
# 1967       NaN   10       61           0  2008              True
# 1968       NaN   10       61          16  2008              True
# 1969       NaN   10       45           0  2008              True
# 1970       NaN   10       45           9  2008              True
#
# [1996 rows x 31 columns]
